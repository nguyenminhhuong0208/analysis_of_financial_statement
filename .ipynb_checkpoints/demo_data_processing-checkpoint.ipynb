# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\admin\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\admin\anaconda3\lib\site-packages (from python-docx) (4.11.0)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
from docx import Document
import pandas as pd

# %%
# Function to extract and preprocess data from tables
def process_tables_to_text(doc_path):
    doc = Document(doc_path)
    texts = []

    # Extract paragraphs
    for paragraph in doc.paragraphs:
        if paragraph.text.strip():
            texts.append(paragraph.text.strip())

    # Extract data from tables and convert to text
    for table in doc.tables:
        for row in table.rows:
            row_text = " | ".join([cell.text.strip() for cell in row.cells if cell.text.strip()])
            if row_text:
                texts.append(f"Table: {row_text}")  # Add prefix to identify table data

    return texts

# File path
doc_path = "Data/00002469135802469136ctcp-bcg-land03022025-000000bo-co-ti-chnh-qu-4-2024-ca-cng-ty-m.docx"

# Extract and convert data
processed_texts = process_tables_to_text(doc_path)

# %%
# 2. Preprocess data
def preprocess_data(df):
    # Remove empty rows/columns
    df.dropna(how='all', inplace=True)
    df.dropna(axis=1, how='all', inplace=True)
    
    # Normalize text
    for col in df.columns:
        if df[col].dtype == 'object':  # Check the data type of each column
            df[col] = df[col].str.lower()  # Convert to lowercase
            df[col] = df[col].str.replace(r'[^\w\s]', '', regex=True)  # Remove special characters
            df[col] = df[col].str.strip()  # Remove extra spaces
    
    return df

# %%
# 1. Extract all tables from a Word file
def extract_tables_from_doc(doc_path):
    doc = Document(doc_path)
    tables = doc.tables
    dataframes = []
    
    if tables:
        print(f"Total number of extracted tables: {len(tables)}")
        
        for i, table in enumerate(tables, start=1):
            # print(f"\nConverting Table {i} to DataFrame...")

            table_data = []
            for row in table.rows:
                row_data = [cell.text.strip() for cell in row.cells]
                table_data.append(row_data)

            df = pd.DataFrame(table_data[1:], columns=table_data[0])
            dataframes.append(df)

            # print(f"DataFrame of Table {i}:")
            # print(df)
    else:
        print("No tables found in the file.")

    return dataframes

# %%
# 4. File path for the Word document
doc_path = "Data_text/00002469135802469136ctcp-bcg-land03022025-000000bo-co-ti-chnh-qu-4-2024-ca-cng-ty-m.docx"

# Extract and convert tables to DataFrames
dataframes = extract_tables_from_doc(doc_path)
# Out:
# Total number of extracted tables: 39

# %%
dataframes[5]
# Out:
#                                                 Items Code   Note  \
# 0        1. Revenues from sales and services rendered   01  V1.01
# 1                               2. Revenue deductions   02
# 2    3. Net revenues from sales and services rendered   10
# 3                              4. Costs of goods sold   11  V1.02
# 4   5. Gross revenues from sales and services rend...   20
# 5                                 6. Financial income   21  V1.03
# 6                               7. Financial expenses   22  VI.04
# 7                       + In which: Interest expenses   23
# 8                                 8. Selling expenses   25
# 9              9. General and administration expenses   26  VI.05
# 10          10. Net profits from operating activities   30
# 11                                   11. Other income   31
# 12                                 12. Other expenses   32  VI.06
# 13                                  13. Other profits   40
# 14             14. Total accounting profit before tax   50
# 15          15. Current corporate income tax expenses   51  VI.08
# 16         16. Deferred corporate income tax expenses   52
# 17             17. Profits after corporate income tax   60
#
#       Quarter IV 2024  Quarter IV 2023  \
# 0       8,706,481,481    8,475,000,000
# 1                   -                -
# 2       8,706,481,481    8,475,000,000
# 3       5,282,860,829    5,060,198,642
# 4       3,423,620,652    3,414,801,358
# 5     168,839,636,375  160,132,029,657
# 6   (3 5,462,743,426)  102,535,983,039
# 7      69,817,049,993   74,008,514,914
# 8                   -                -
# 9      16,062,706,980   28,274,085,931
# 10    191,663,293,473   32,736,762,045
# 11                  -                -
# 12        771,423,796    1,559,930,810
# 13      (771,423,796)  (1,559,930,810)
# 14    190,891,869,677   31,176,831,235
# 15   3 8,3 85,275,228    9,501,703,429
# 16                  -  (2,159,025,753)
# 17    152,506,594,449   23,834,153,559
#
#    Accumulated to the end of Quarter IV.2024  \
# 0                             34,131,481,481
# 1                                          -
# 2                             34,131,481,481
# 3                            19,3 54,540,087
# 4                             14,776,941,394
# 5                            582,397,303,126
# 6                            232,263,390,733
# 7                            285,553,122,895
# 8                                          -
# 9                             46,368,335,390
# 10                           318,542,518,397
# 11                            31,923,549,345
# 12                             6,318,767,984
# 13                            25,604,781,361
# 14                           344,147,299,758
# 15                            70,307,428,322
# 16                                         -
# 17                           273,839,871,436
#
#    Accumulated to the end of Quarter IV.2023
# 0                             33,900,000,000
# 1                                          -
# 2                             33,900,000,000
# 3                             21,403,991,212
# 4                             12,496,008,788
# 5                            539,786,865,921
# 6                            425,789,232,726
# 7                            311,196,207,462
# 8                                          -
# 9                             62,515,699,294
# 10                            63,977,942,689
# 11                                         -
# 12                             6,443,116,666
# 13                           (6,443,116,666)
# 14                            57,534,826,023
# 15                            15,912,779,191
# 16                           (2,159,025,753)
# 17                            43,781,072,585

# %%
dataframes=[(dataframes[2], "Balance Sheet"), (dataframes[4],"Balance Sheet"), (dataframes[5], "Income Statement"), 
            (dataframes[6],"Cash Flow Statement"), (dataframes[7],"Cash Flow Statement")]

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.51.0

# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1

# %%
pip uninstall transformers torch
pip install transformers==4.36.2 torch==2.1.0

# %%
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
import torch

# Tải FinBERT mà không dùng context đặc biệt
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
model = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone')
model.eval()  # Đặt mô hình ở chế độ đánh giá
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 # Tải FinBERT mà không dùng context đặc biệt
#       6 tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
# ----> 7 model = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone')
#       8 model.eval()
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:279, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     277 old_dtype = torch.get_default_dtype()
#     278 try:
# --> 279     return func(*args, **kwargs)
#     280 finally:
#     281     torch.set_default_dtype(old_dtype)
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:4333, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4330 config.name_or_path = pretrained_model_name_or_path
#    4332 # Instantiate model.
# -> 4333 model_init_context = cls.get_init_context(is_quantized, _is_ds_init_called)
#    4335 config = copy.deepcopy(config)  # We do not want to modify the config inplace in from_pretrained.
#    4336 if not getattr(config, "_attn_implementation_autoset", False):
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:3736, in PreTrainedModel.get_init_context(cls, is_quantized, _is_ds_init_called)
#    3734         init_contexts.append(set_quantized_state())
#    3735 else:
# -> 3736     init_contexts = [no_init_weights(), init_empty_weights()]
#    3738 return init_contexts
#
# NameError: name 'init_empty_weights' is not defined

# %%
# Hàm chuyển DataFrame thành văn bản có ý nghĩa
def dataframe_to_text(df, statement_type):
    text = f"{statement_type} Analysis:\n"
    for index, row in df.iterrows():
        # Chuyển dòng thành câu văn
        row_text = " ".join([f"{col}: {val}" for col, val in row.items() if pd.notna(val)])
        text += f"{row_text}\n"
    return text

# Hàm phân tích cảm xúc bằng FinBERT
def analyze_sentiment(text):
    # Tokenize văn bản
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512, padding=True)
    
    # Dự đoán với FinBERT
    with torch.no_grad():
        outputs = model(**inputs)
        probs = softmax(outputs.logits, dim=1)
        sentiment_scores = probs[0].tolist()  # [negative, neutral, positive]
    
    labels = ['Negative', 'Neutral', 'Positive']
    sentiment = labels[sentiment_scores.index(max(sentiment_scores))]
    return sentiment, sentiment_scores


# Xử lý và phân tích từng bảng
for df, statement_type in dataframes:
    # Chuyển DataFrame thành văn bản
    text = dataframe_to_text(df, statement_type)
    print(f"\n{statement_type} Text:")
    print(text)
    
    # Phân tích cảm xúc
    sentiment, scores = analyze_sentiment(text)
    print(f"\n{statement_type} Sentiment Analysis:")
    print(f"Sentiment: {sentiment}")
    print(f"Scores: Negative: {scores[0]:.4f}, Neutral: {scores[1]:.4f}, Positive: {scores[2]:.4f}")

# Phân tích tổng quan
combined_text = "\n".join([dataframe_to_text(df, statement_type) for df, statement_type in financial_statements])
overall_sentiment, overall_scores = analyze_sentiment(combined_text)
print("\nOverall Financial Statement Sentiment Analysis:")
print(f"Sentiment: {overall_sentiment}")
print(f"Scores: Negative: {overall_scores[0]:.4f}, Neutral: {overall_scores[1]:.4f}, Positive: {overall_scores[2]:.4f}")
